# %% [markdown]
# ## Submitted  by: VANSHIKA SINGH (590010685)

# %% [markdown]
# # ASSIGNMENT 1

# %% [markdown]
# ## PART 1 - Introduction to Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import platform
name = "VANSHIKA SINGH"
course = "MCA"
print("Name:", name)
print("Course Name:", course)
print("Python Version:", platform.python_version() )
# Out:
# Name: VANSHIKA SINGH
# Course Name: MCA
# Python Version: 3.12.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Part 1 - Question 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Part 2 - Basic Python Syntax

# %% [markdown]
# # 1. String Operations

# %% [markdown]
# ## Question 1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Solution 1:

# %%
# #get user's first and last name as input
# first_name=input("Enter your first name:")
# last_name=input("Enter your last name:")

# # print the full name in reverse order
# print("Your name in  reverse order is:", last_name + " " +first_name)


# user input
first_name = input("Enter your first name ")
last_name = input("Enter your last name ")

#  reverse order print
print(last_name + " " + first_name)
# Out:
# Enter your first name vanshika
# Enter your last name singh
# singh vanshika

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution:

# %%
#Strings methods used are
#lower() : returns a string where all characters are in lower case.
#upper() : returns a string where all characters are in upper case.

# working of upper() function
text = 'HellO World!!'

# upper() function to convert
# string to upper case
print("\nConverted String in upper  case:")
print(text.upper())

# lower() function to convert
# string to lower case
print("\nConverted String in lowers case:")
print(text.lower())
# Out:
# Converted String in upper  case:
# HELLO WORLD!!
#
# Converted String in lowers case:
# hello world!!

# %% [markdown]
# # 2. Numeric Data Types and Conversion Functions

# %% [markdown]
# ## Question 2:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 2:

# %%
# Get input from user
user_input = input("Enter a number: ")

# Convert input to different numeric data types
try:
    # Convert to integer data type :
    integer_value = int(user_input)
    print(f"Integer value: {integer_value}")
except ValueError:
    print("Invalid input for integer conversion.")

try:
    # Convert to float data type :
    float_value = float(user_input)
    print(f"Float value: {float_value}")
except ValueError:
    print("Invalid input for float conversion.")

try:
    # Convert to complex data type :
    complex_value = complex(user_input)
    print(f"Complex value: {complex_value}")
except ValueError:
    print("Invalid input for complex conversion.")
# Out:
# Integer value: 34
# Float value: 34.0
# Complex value: (34+0j)

# %% [markdown]
# ## Question 3:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 3:

# %%
#taking user's input of length and width
length=int(input("Enter the length of rectangle:"))
width=int(input("Enter the width of rectangle:"))
area=length*width
print(area)
# Out:
# Enter the length of rectangle:10
# Enter the width of rectangle:20
# 200

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Using format method
# taking input of length and width
length=int(input("Enter the length of rectangle:"))
width=int(input("Enter the width of rectangle:"))
area= length*width
print(f"The area of the rectangle is {area:.2f}")
# Out:
# Enter the length of rectangle:40
# Enter the width of rectangle:50
# The area of the rectangle is 2000.00

# %% [markdown]
# ## Question 3 part 2:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 3 part 2:

# %%
# taking input from user
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
num3=int(input("Enter the third number:"))

# Calculating the average:
calculate_average = (num1 + num2 + num3) / 3

# Print the average using % formatting
print(f"The average of the three number is: %.2f" % calculate_average)
# Out:
# Enter the first number:98
# Enter the second number:88
# Enter the third number:34
# The average of the three number is: 73.33

# %% [markdown]
# # Part 3 Language Components

# %% [markdown]
# ## Question 1:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Solution 1:

# %%
# take input from user
num=float(input("Enter a number:"))

# to check whether the number is positive, negative or zero
if num>0:
  print("The number is positive.")
elif num<0:
   print("The number is negative.")
else:
   print("The number is zero.")
# Out:
# Enter a number:-67
# The number is negative.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Implementing a loop that continuesto ask the user for a nummber until they enter exit
while True:
    user_input = input("Enter a number (or type 'Exit' to quit): ")
    # Check if the user wants to exit
    if user_input.lower() == 'exit':
        print("Exiting the program.")
        break

    # Try to convert the input to a float using exceptional handling
    try:
        num = float(user_input)
        if num > 0:
            print("The number is positive.")
        elif num < 0:
            print("The number is negative.")
        else:
            print("The number is zero.")
    except ValueError:
        print("Please enter a valid number or 'exit' to quit.")
# Out:
# Enter a number (or type 'Exit' to quit): 4
# The number is positive.
# Enter a number (or type 'Exit' to quit): 5
# The number is positive.
# Enter a number (or type 'Exit' to quit): 6
# The number is positive.
# Enter a number (or type 'Exit' to quit): 7
# The number is positive.
# Enter a number (or type 'Exit' to quit): -0
# The number is zero.
# Enter a number (or type 'Exit' to quit): -11
# The number is negative.
# Enter a number (or type 'Exit' to quit): exit
# Exiting the program.

# %% [markdown]
# ## Part 2:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 2:

# %%
# Taking input from the user
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number:"))

# To check if both numbers are even or odd
if num % 2 == 0 and num2 % 2 == 0:
  print("Both numbers are even.")
elif num1 % 2 != 0 and num2 % 2 !=0:
  print("Both numbers are odd.")
else:
  print("One number is even and the other number is odd.")
# Out:
# Enter the first number:9
# Enter the second number:8
# One number is even and the other number is odd.

# %% [markdown]
# ## Part 3:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 3:

# %%
# Function to convert an integer to binary, octal, and hexadecimal
def convert_number(num):
    # Initialize empty strings for binary, octal, and hexadecimal
    binary = ""
    octal = ""
    hexadecimal = ""

    # Convert to binary using bitwise operators
    for i in range(31, -1, -1):  # Loop from 31 to 0 for a 32-bit representation
        if num & (1 << i):  # Check if the ith bit is set
            binary += "1"
        else:
            binary += "0"

    # Remove leading zeros from binary representation
    binary = binary.lstrip("0") or "0"  # Ensure at least one '0' if the number is 0

    # Convert to octal using bitwise operators
    temp_num = num
    while temp_num > 0:
        octal = str(temp_num & 7) + octal  # Get the last 3 bits (octal digit)
        temp_num >>= 3  # Right shift by 3 bits to process the next octal digit

    # If the number is 0, set octal to "0"
    if num == 0:
        octal = "0"

    # Convert to hexadecimal using bitwise operators
    temp_num = num
    while temp_num > 0:
        hex_digit = temp_num & 15  # Get the last 4 bits (hexadecimal digit)
        if hex_digit < 10:
            hexadecimal = str(hex_digit) + hexadecimal  # Convert to string
        else:
            hexadecimal = chr(hex_digit - 10 + ord('A')) + hexadecimal  # Convert to A-F
        temp_num >>= 4  # Right shift by 4 bits to process the next hex digit

    # If the number is 0, set hexadecimal to "0"
    if num == 0:
        hexadecimal = "0"

    return binary, octal, hexadecimal

# Get user input
try:
    number = int(input("Enter an integer: "))  # Prompt for an integer

    # Convert the number and get its representations
    binary_rep, octal_rep, hex_rep = convert_number(number)

    # Display the results
    print(f"Binary: {binary_rep}")
    print(f"Octal: {octal_rep}")
    print(f"Hexadecimal: {hex_rep}")
except ValueError:
    print("Please enter a valid integer.")
# Out:
# Enter an integer: 89
# Binary: 1011001
# Octal: 131
# Hexadecimal: 59
